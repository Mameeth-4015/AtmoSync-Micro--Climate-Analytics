# %%
## installation libraries pandas, numpy, matplotlib, seaborn.

# %%
# %pip install pandas 
# %pip install numpy
# %pip install matplotlib
# %pip install seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# importing libraries with  allias name

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
## Load the dataset

# %%
df = pd.read_csv("atmosync_dataset.csv")

# %%
# head--checking the first 5 rows of the dataset

# %%
df.head()
# Out:
#    reading_id container_id commodity                   timestamp  \
# 0           1    CONT-0001   Avocado  2026-07-03 17:23:04.628550
# 1           2    CONT-0001   Avocado  2026-07-03 17:53:04.628550
# 2           3    CONT-0001   Avocado  2026-07-03 18:23:04.628550
# 3           4    CONT-0001   Avocado  2026-07-03 18:53:04.628550
# 4           5    CONT-0001   Avocado  2026-07-03 19:23:04.628550
#
#    hours_in_transit  temperature_c  humidity_pct  vibration_g  \
# 0               0.0           5.31         88.29        0.220
# 1               0.5           5.99         92.25        0.187
# 2               1.0           5.10         88.08        0.220
# 3               1.5           5.41         88.64        0.248
# 4               2.0           5.28         89.30        0.193
#
#    ideal_temp_min_c  ideal_temp_max_c  ...  quality_score  \
# 0                 4                 7  ...          99.98
# 1                 4                 7  ...          99.95
# ...

# %%
## shape--checking the number of rows and columns in the dataset

# %%
df.shape
# Out:
# (50000, 30)

# %%
# describe--checking the statistical summary of the dataset

# %%
df.describe()
# Out:
#          reading_id  hours_in_transit  temperature_c  humidity_pct  \
# count  50000.000000       50000.00000   50000.000000  50000.000000
# mean   25000.500000          24.59565       6.624175     89.974576
# std    14433.901067          14.43875       5.710725      3.228729
# min        1.000000           0.00000      -2.710000     73.840000
# 25%    12500.750000          12.00000       0.980000     87.870000
# 50%    25000.500000          24.50000       5.590000     90.190000
# 75%    37500.250000          37.00000      11.800000     92.300000
# max    50000.000000          49.50000      24.170000     99.000000
#
#         vibration_g  ideal_temp_min_c  ideal_temp_max_c  \
# count  50000.000000      50000.000000      50000.000000
# mean       0.170556          4.938820          7.346540
# std        0.188111          5.355794          5.583837
# min        0.000000         -1.000000          1.000000
# 25%        0.097000          0.000000          2.000000
# ...

# %%
## columns--checking the column names in the dataset

# %%
df.columns
# Out:
# Index(['reading_id', 'container_id', 'commodity', 'timestamp',
#        'hours_in_transit', 'temperature_c', 'humidity_pct', 'vibration_g',
#        'ideal_temp_min_c', 'ideal_temp_max_c', 'ideal_humidity_min_pct',
#        'ideal_humidity_max_pct', 'temp_deviation_c', 'humidity_deviation_pct',
#        'origin_port', 'primary_market', 'secondary_market',
#        'distance_primary_km', 'distance_secondary_km', 'quantity_kg',
#        'quality_score', 'shelf_life_hours_remaining',
#        'primary_price_per_kg_usd', 'secondary_price_per_kg_usd',
#        'primary_net_value_usd', 'secondary_net_value_usd',
#        'arbitrage_gain_usd', 'risk_status', 'recommended_action',
#        'cooling_unit_faulty'],
#       dtype='object')

# %%
# dtype--checking the data types of each column in the dataset

# %%
df.dtypes
# Out:
# reading_id                      int64
# container_id                   object
# commodity                      object
# timestamp                      object
# hours_in_transit              float64
# temperature_c                 float64
# humidity_pct                  float64
# vibration_g                   float64
# ideal_temp_min_c                int64
# ideal_temp_max_c                int64
# ideal_humidity_min_pct          int64
# ideal_humidity_max_pct          int64
# temp_deviation_c              float64
# humidity_deviation_pct        float64
# origin_port                    object
# primary_market                 object
# secondary_market               object
# distance_primary_km             int64
# distance_secondary_km           int64
# quantity_kg                     int64
# quality_score                 float64
# shelf_life_hours_remaining    float64
# primary_price_per_kg_usd      float64
# secondary_price_per_kg_usd    float64
# primary_net_value_usd         float64
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df = df.drop_duplicates()

# %%
df.isnull().sum()
# Out:
# reading_id                    0
# container_id                  0
# commodity                     0
# timestamp                     0
# hours_in_transit              0
# temperature_c                 0
# humidity_pct                  0
# vibration_g                   0
# ideal_temp_min_c              0
# ideal_temp_max_c              0
# ideal_humidity_min_pct        0
# ideal_humidity_max_pct        0
# temp_deviation_c              0
# humidity_deviation_pct        0
# origin_port                   0
# primary_market                0
# secondary_market              0
# distance_primary_km           0
# distance_secondary_km         0
# quantity_kg                   0
# quality_score                 0
# shelf_life_hours_remaining    0
# primary_price_per_kg_usd      0
# secondary_price_per_kg_usd    0
# primary_net_value_usd         0
# secondary_net_value_usd       0
# arbitrage_gain_usd            0
# risk_status                   0
# recommended_action            0
# ...

# %%
df.isnull().sum() / len(df) * 100
# Out:
# reading_id                    0.0
# container_id                  0.0
# commodity                     0.0
# timestamp                     0.0
# hours_in_transit              0.0
# temperature_c                 0.0
# humidity_pct                  0.0
# vibration_g                   0.0
# ideal_temp_min_c              0.0
# ideal_temp_max_c              0.0
# ideal_humidity_min_pct        0.0
# ideal_humidity_max_pct        0.0
# temp_deviation_c              0.0
# humidity_deviation_pct        0.0
# origin_port                   0.0
# primary_market                0.0
# secondary_market              0.0
# distance_primary_km           0.0
# distance_secondary_km         0.0
# quantity_kg                   0.0
# quality_score                 0.0
# shelf_life_hours_remaining    0.0
# primary_price_per_kg_usd      0.0
# secondary_price_per_kg_usd    0.0
# primary_net_value_usd         0.0
# secondary_net_value_usd       0.0
# arbitrage_gain_usd            0.0
# ...

# %%
df['ttimestamp'] = pd.to_datetime(df['timestamp'], errors='coerce')

# %%
df['timestamp'].dtype
# Out:
# dtype('O')

# %%
df['timestamp']
# Out:
# 0        2026-07-03 17:23:04.628550
# 1        2026-07-03 17:53:04.628550
# 2        2026-07-03 18:23:04.628550
# 3        2026-07-03 18:53:04.628550
# 4        2026-07-03 19:23:04.628550
#                     ...
# 49995    2026-07-04 21:23:45.058068
# 49996    2026-07-04 21:53:45.058068
# 49997    2026-07-04 22:23:45.058068
# 49998    2026-07-04 23:23:45.058068
# 49999    2026-07-04 23:53:45.058068
# Name: timestamp, Length: 50000, dtype: object

# %%
# df.columns --checking the column names in the dataset
# str.strip() --removes leading and trailing whitespace from each column name
# str.lower() --converts each column name to lowercase
# str.replace(' ', '_') --replaces spaces with underscores in each column name

# %%
df.columns = df.columns.str.strip().str.lower().str.replace(' ', '_')

# %%
# df.rename --renames the column 'timestamp' to 'Date_Time' in the dataset
# implace=True --modifies the original DataFrame instead of creating a new one

# %%
df.rename(columns={'timestamp': 'Date_Time'}, inplace=True)

# %%
# df.columns --checking the column names in the dataset

# %%
df.columns
# Out:
# Index(['reading_id', 'container_id', 'commodity', 'Date_Time',
#        'hours_in_transit', 'temperature_c', 'humidity_pct', 'vibration_g',
#        'ideal_temp_min_c', 'ideal_temp_max_c', 'ideal_humidity_min_pct',
#        'ideal_humidity_max_pct', 'temp_deviation_c', 'humidity_deviation_pct',
#        'origin_port', 'primary_market', 'secondary_market',
#        'distance_primary_km', 'distance_secondary_km', 'quantity_kg',
#        'quality_score', 'shelf_life_hours_remaining',
#        'primary_price_per_kg_usd', 'secondary_price_per_kg_usd',
#        'primary_net_value_usd', 'secondary_net_value_usd',
#        'arbitrage_gain_usd', 'risk_status', 'recommended_action',
#        'cooling_unit_faulty', 'ttimestamp'],
#       dtype='object')

# %%
df.head()
# Out:
#    reading_id container_id commodity                   Date_Time  \
# 0           1    CONT-0001   Avocado  2026-07-03 17:23:04.628550
# 1           2    CONT-0001   Avocado  2026-07-03 17:53:04.628550
# 2           3    CONT-0001   Avocado  2026-07-03 18:23:04.628550
# 3           4    CONT-0001   Avocado  2026-07-03 18:53:04.628550
# 4           5    CONT-0001   Avocado  2026-07-03 19:23:04.628550
#
#    hours_in_transit  temperature_c  humidity_pct  vibration_g  \
# 0               0.0           5.31         88.29        0.220
# 1               0.5           5.99         92.25        0.187
# 2               1.0           5.10         88.08        0.220
# 3               1.5           5.41         88.64        0.248
# 4               2.0           5.28         89.30        0.193
#
#    ideal_temp_min_c  ideal_temp_max_c  ...  shelf_life_hours_remaining  \
# 0                 4                 7  ...                      2041.8
# ...

# %%
df.ttimestamp.dropna(inplace=True)

# %%
df.columns
# Out:
# Index(['reading_id', 'container_id', 'commodity', 'Date_Time',
#        'hours_in_transit', 'temperature_c', 'humidity_pct', 'vibration_g',
#        'ideal_temp_min_c', 'ideal_temp_max_c', 'ideal_humidity_min_pct',
#        'ideal_humidity_max_pct', 'temp_deviation_c', 'humidity_deviation_pct',
#        'origin_port', 'primary_market', 'secondary_market',
#        'distance_primary_km', 'distance_secondary_km', 'quantity_kg',
#        'quality_score', 'shelf_life_hours_remaining',
#        'primary_price_per_kg_usd', 'secondary_price_per_kg_usd',
#        'primary_net_value_usd', 'secondary_net_value_usd',
#        'arbitrage_gain_usd', 'risk_status', 'recommended_action',
#        'cooling_unit_faulty', 'ttimestamp'],
#       dtype='object')

# %%
df.head()
# Out:
#    reading_id container_id commodity                   Date_Time  \
# 0           1    CONT-0001   Avocado  2026-07-03 17:23:04.628550
# 1           2    CONT-0001   Avocado  2026-07-03 17:53:04.628550
# 2           3    CONT-0001   Avocado  2026-07-03 18:23:04.628550
# 3           4    CONT-0001   Avocado  2026-07-03 18:53:04.628550
# 4           5    CONT-0001   Avocado  2026-07-03 19:23:04.628550
#
#    hours_in_transit  temperature_c  humidity_pct  vibration_g  \
# 0               0.0           5.31         88.29        0.220
# 1               0.5           5.99         92.25        0.187
# 2               1.0           5.10         88.08        0.220
# 3               1.5           5.41         88.64        0.248
# 4               2.0           5.28         89.30        0.193
#
#    ideal_temp_min_c  ideal_temp_max_c  ...  shelf_life_hours_remaining  \
# 0                 4                 7  ...                      2041.8
# ...

# %%
df = df.drop(columns=['ttimestamp'])

# %%
df.head()
# Out:
#    reading_id container_id commodity                   Date_Time  \
# 0           1    CONT-0001   Avocado  2026-07-03 17:23:04.628550
# 1           2    CONT-0001   Avocado  2026-07-03 17:53:04.628550
# 2           3    CONT-0001   Avocado  2026-07-03 18:23:04.628550
# 3           4    CONT-0001   Avocado  2026-07-03 18:53:04.628550
# 4           5    CONT-0001   Avocado  2026-07-03 19:23:04.628550
#
#    hours_in_transit  temperature_c  humidity_pct  vibration_g  \
# 0               0.0           5.31         88.29        0.220
# 1               0.5           5.99         92.25        0.187
# 2               1.0           5.10         88.08        0.220
# 3               1.5           5.41         88.64        0.248
# 4               2.0           5.28         89.30        0.193
#
#    ideal_temp_min_c  ideal_temp_max_c  ...  quality_score  \
# 0                 4                 7  ...          99.98
# 1                 4                 7  ...          99.95
# ...

# %%
df["commodity"] = df["commodity"].astype("category")

# %%
df.dtypes
# Out:
# reading_id                       int64
# container_id                    object
# commodity                     category
# Date_Time                       object
# hours_in_transit               float64
# temperature_c                  float64
# humidity_pct                   float64
# vibration_g                    float64
# ideal_temp_min_c                 int64
# ideal_temp_max_c                 int64
# ideal_humidity_min_pct           int64
# ideal_humidity_max_pct           int64
# temp_deviation_c               float64
# humidity_deviation_pct         float64
# origin_port                     object
# primary_market                  object
# secondary_market                object
# distance_primary_km              int64
# distance_secondary_km            int64
# quantity_kg                      int64
# quality_score                  float64
# shelf_life_hours_remaining     float64
# primary_price_per_kg_usd       float64
# secondary_price_per_kg_usd     float64
# ...

# %%
df["origin_port"] = df["origin_port"].astype("category")
df["primary_market"] = df["primary_market"].astype("category")
df["secondary_market"] = df["secondary_market"].astype("category")
df["risk_status"] = df["risk_status"].astype("category")
df["recommended_action"] = df["recommended_action"].astype("category")

# %%
df.dtypes
# Out:
# reading_id                       int64
# container_id                    object
# commodity                     category
# Date_Time                       object
# hours_in_transit               float64
# temperature_c                  float64
# humidity_pct                   float64
# vibration_g                    float64
# ideal_temp_min_c                 int64
# ideal_temp_max_c                 int64
# ideal_humidity_min_pct           int64
# ideal_humidity_max_pct           int64
# temp_deviation_c               float64
# humidity_deviation_pct         float64
# origin_port                   category
# primary_market                category
# secondary_market              category
# distance_primary_km              int64
# distance_secondary_km            int64
# quantity_kg                      int64
# quality_score                  float64
# shelf_life_hours_remaining     float64
# primary_price_per_kg_usd       float64
# secondary_price_per_kg_usd     float64
# ...

# %%
df["cooling_unit_faulty"] = df["cooling_unit_faulty"].astype("bool")

# %%
df.dtypes
# Out:
# reading_id                       int64
# container_id                    object
# commodity                     category
# Date_Time                       object
# hours_in_transit               float64
# temperature_c                  float64
# humidity_pct                   float64
# vibration_g                    float64
# ideal_temp_min_c                 int64
# ideal_temp_max_c                 int64
# ideal_humidity_min_pct           int64
# ideal_humidity_max_pct           int64
# temp_deviation_c               float64
# humidity_deviation_pct         float64
# origin_port                   category
# primary_market                category
# secondary_market              category
# distance_primary_km              int64
# distance_secondary_km            int64
# quantity_kg                      int64
# quality_score                  float64
# shelf_life_hours_remaining     float64
# primary_price_per_kg_usd       float64
# secondary_price_per_kg_usd     float64
# ...

# %%
df['commodity'].value_counts()
# Out:
# commodity
# Avocado       7808
# Blueberry     7670
# Banana        7478
# Tomato        7437
# Grapes        7285
# Strawberry    7181
# Mango         5141
# Name: count, dtype: int64

# %%
df = df.sort_values(['container_id', 'Date_Time']).reset_index(drop=True)

# %%
df.head()
# Out:
#    reading_id container_id commodity                   Date_Time  \
# 0           1    CONT-0001   Avocado  2026-07-03 17:23:04.628550
# 1           2    CONT-0001   Avocado  2026-07-03 17:53:04.628550
# 2           3    CONT-0001   Avocado  2026-07-03 18:23:04.628550
# 3           4    CONT-0001   Avocado  2026-07-03 18:53:04.628550
# 4           5    CONT-0001   Avocado  2026-07-03 19:23:04.628550
#
#    hours_in_transit  temperature_c  humidity_pct  vibration_g  \
# 0               0.0           5.31         88.29        0.220
# 1               0.5           5.99         92.25        0.187
# 2               1.0           5.10         88.08        0.220
# 3               1.5           5.41         88.64        0.248
# 4               2.0           5.28         89.30        0.193
#
#    ideal_temp_min_c  ideal_temp_max_c  ...  quality_score  \
# 0                 4                 7  ...          99.98
# 1                 4                 7  ...          99.95
# ...

# %%
df["origin_port"] = df["origin_port"].str.strip()

# %%
df["origin_port"].value_counts()
# Out:
# origin_port
# Guayaquil Port (EC)    8559
# Tangier Port (MA)      8471
# Mombasa Port (KE)      7179
# Chennai Port (IN)      6879
# Veracruz Port (MX)     6553
# Durban Port (ZA)       6471
# Callao Port (PE)       5888
# Name: count, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 30 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   reading_id                  50000 non-null  int64
#  1   container_id                50000 non-null  object
#  2   commodity                   50000 non-null  category
#  3   Date_Time                   50000 non-null  object
#  4   hours_in_transit            50000 non-null  float64
#  5   temperature_c               50000 non-null  float64
#  6   humidity_pct                50000 non-null  float64
#  7   vibration_g                 50000 non-null  float64
#  8   ideal_temp_min_c            50000 non-null  int64
#  9   ideal_temp_max_c            50000 non-null  int64
#  10  ideal_humidity_min_pct      50000 non-null  int64
#  11  ideal_humidity_max_pct      50000 non-null  int64
#  12  temp_deviation_c            50000 non-null  float64
# ...

# %%
df["data_quality_flag"] = "Normal Reading"
df.loc[df["temp_deviation_c"] > 3, "data_quality_flag"] = "Significant Temperature Drift"

# %%
df.head()
# Out:
#    reading_id container_id commodity                   Date_Time  \
# 0           1    CONT-0001   Avocado  2026-07-03 17:23:04.628550
# 1           2    CONT-0001   Avocado  2026-07-03 17:53:04.628550
# 2           3    CONT-0001   Avocado  2026-07-03 18:23:04.628550
# 3           4    CONT-0001   Avocado  2026-07-03 18:53:04.628550
# 4           5    CONT-0001   Avocado  2026-07-03 19:23:04.628550
#
#    hours_in_transit  temperature_c  humidity_pct  vibration_g  \
# 0               0.0           5.31         88.29        0.220
# 1               0.5           5.99         92.25        0.187
# 2               1.0           5.10         88.08        0.220
# 3               1.5           5.41         88.64        0.248
# 4               2.0           5.28         89.30        0.193
#
#    ideal_temp_min_c  ideal_temp_max_c  ...  shelf_life_hours_remaining  \
# 0                 4                 7  ...                      2041.8
# ...

# %%
df.tail()
# Out:
#        reading_id container_id  commodity                   Date_Time  \
# 49995       49996    CONT-0550  Blueberry  2026-07-04 21:23:45.058068
# 49996       49997    CONT-0550  Blueberry  2026-07-04 21:53:45.058068
# 49997       49998    CONT-0550  Blueberry  2026-07-04 22:23:45.058068
# 49998       49999    CONT-0550  Blueberry  2026-07-04 23:23:45.058068
# 49999       50000    CONT-0550  Blueberry  2026-07-04 23:53:45.058068
#
#        hours_in_transit  temperature_c  humidity_pct  vibration_g  \
# 49995              47.0           1.39         92.35        0.189
# 49996              47.5           0.12         92.69        0.273
# 49997              48.0           2.67         91.53        0.156
# 49998              49.0           0.91         91.65        0.284
# 49999              49.5           0.90         92.60        0.064
#
#        ideal_temp_min_c  ideal_temp_max_c  ...  shelf_life_hours_remaining  \
# ...

# %%
(df["ideal_temp_min_c"] >= df["ideal_temp_max_c"]).sum()
# Out:
# np.int64(0)

# %%
df.head()
# Out:
#    reading_id container_id commodity                   Date_Time  \
# 0           1    CONT-0001   Avocado  2026-07-03 17:23:04.628550
# 1           2    CONT-0001   Avocado  2026-07-03 17:53:04.628550
# 2           3    CONT-0001   Avocado  2026-07-03 18:23:04.628550
# 3           4    CONT-0001   Avocado  2026-07-03 18:53:04.628550
# 4           5    CONT-0001   Avocado  2026-07-03 19:23:04.628550
#
#    hours_in_transit  temperature_c  humidity_pct  vibration_g  \
# 0               0.0           5.31         88.29        0.220
# 1               0.5           5.99         92.25        0.187
# 2               1.0           5.10         88.08        0.220
# 3               1.5           5.41         88.64        0.248
# 4               2.0           5.28         89.30        0.193
#
#    ideal_temp_min_c  ideal_temp_max_c  ...  shelf_life_hours_remaining  \
# 0                 4                 7  ...                      2041.8
# ...

# %%
df.shape
# Out:
# (50000, 31)

# %%
df.describe()
# Out:
#          reading_id  hours_in_transit  temperature_c  humidity_pct  \
# count  50000.000000       50000.00000   50000.000000  50000.000000
# mean   25000.500000          24.59565       6.624175     89.974576
# std    14433.901067          14.43875       5.710725      3.228729
# min        1.000000           0.00000      -2.710000     73.840000
# 25%    12500.750000          12.00000       0.980000     87.870000
# 50%    25000.500000          24.50000       5.590000     90.190000
# 75%    37500.250000          37.00000      11.800000     92.300000
# max    50000.000000          49.50000      24.170000     99.000000
#
#         vibration_g  ideal_temp_min_c  ideal_temp_max_c  \
# count  50000.000000      50000.000000      50000.000000
# mean       0.170556          4.938820          7.346540
# std        0.188111          5.355794          5.583837
# min        0.000000         -1.000000          1.000000
# 25%        0.097000          0.000000          2.000000
# ...

# %%
df.columns
# Out:
# Index(['reading_id', 'container_id', 'commodity', 'Date_Time',
#        'hours_in_transit', 'temperature_c', 'humidity_pct', 'vibration_g',
#        'ideal_temp_min_c', 'ideal_temp_max_c', 'ideal_humidity_min_pct',
#        'ideal_humidity_max_pct', 'temp_deviation_c', 'humidity_deviation_pct',
#        'origin_port', 'primary_market', 'secondary_market',
#        'distance_primary_km', 'distance_secondary_km', 'quantity_kg',
#        'quality_score', 'shelf_life_hours_remaining',
#        'primary_price_per_kg_usd', 'secondary_price_per_kg_usd',
#        'primary_net_value_usd', 'secondary_net_value_usd',
#        'arbitrage_gain_usd', 'risk_status', 'recommended_action',
#        'cooling_unit_faulty', 'data_quality_flag'],
#       dtype='object')

# %%
df.dtypes
# Out:
# reading_id                       int64
# container_id                    object
# commodity                     category
# Date_Time                       object
# hours_in_transit               float64
# temperature_c                  float64
# humidity_pct                   float64
# vibration_g                    float64
# ideal_temp_min_c                 int64
# ideal_temp_max_c                 int64
# ideal_humidity_min_pct           int64
# ideal_humidity_max_pct           int64
# temp_deviation_c               float64
# humidity_deviation_pct         float64
# origin_port                     object
# primary_market                category
# secondary_market              category
# distance_primary_km              int64
# distance_secondary_km            int64
# quantity_kg                      int64
# quality_score                  float64
# shelf_life_hours_remaining     float64
# primary_price_per_kg_usd       float64
# secondary_price_per_kg_usd     float64
# ...

# %%
df.isnull().sum()
# Out:
# reading_id                    0
# container_id                  0
# commodity                     0
# Date_Time                     0
# hours_in_transit              0
# temperature_c                 0
# humidity_pct                  0
# vibration_g                   0
# ideal_temp_min_c              0
# ideal_temp_max_c              0
# ideal_humidity_min_pct        0
# ideal_humidity_max_pct        0
# temp_deviation_c              0
# humidity_deviation_pct        0
# origin_port                   0
# primary_market                0
# secondary_market              0
# distance_primary_km           0
# distance_secondary_km         0
# quantity_kg                   0
# quality_score                 0
# shelf_life_hours_remaining    0
# primary_price_per_kg_usd      0
# secondary_price_per_kg_usd    0
# primary_net_value_usd         0
# secondary_net_value_usd       0
# arbitrage_gain_usd            0
# risk_status                   0
# recommended_action            0
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df = df.to_csv("cleaned_dataset.csv", index=False)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_theme(style="whitegrid")
plt.rcParams["figure.figsize"] = (9, 6)

df = pd.read_csv("cleaned_dataset.csv", parse_dates=["Date_Time"])
df.head()
# Out:
#    reading_id container_id commodity                  Date_Time  \
# 0           1    CONT-0001   Avocado 2026-07-03 17:23:04.628550
# 1           2    CONT-0001   Avocado 2026-07-03 17:53:04.628550
# 2           3    CONT-0001   Avocado 2026-07-03 18:23:04.628550
# 3           4    CONT-0001   Avocado 2026-07-03 18:53:04.628550
# 4           5    CONT-0001   Avocado 2026-07-03 19:23:04.628550
#
#    hours_in_transit  temperature_c  humidity_pct  vibration_g  \
# 0               0.0           5.31         88.29        0.220
# 1               0.5           5.99         92.25        0.187
# 2               1.0           5.10         88.08        0.220
# 3               1.5           5.41         88.64        0.248
# 4               2.0           5.28         89.30        0.193
#
#    ideal_temp_min_c  ideal_temp_max_c  ...  shelf_life_hours_remaining  \
# 0                 4                 7  ...                      2041.8
# ...

# %%
container = df["container_id"].unique()[0]
sub = df[df["container_id"] == container]

plt.figure()
plt.plot(sub["hours_in_transit"], sub["temperature_c"], label="Actual Temp (°C)")
plt.axhline(sub["ideal_temp_min_c"].iloc[0], color="green", ls="--", label="Ideal Min")
plt.axhline(sub["ideal_temp_max_c"].iloc[0], color="red", ls="--", label="Ideal Max")
plt.title(f"Temperature Over Transit — {container} ({sub['commodity'].iloc[0]})")
plt.xlabel("Hours in Transit")
plt.ylabel("Temperature (°C)")
plt.legend()
plt.tight_layout()
plt.savefig("chart1_temperature_trace.png", dpi=150)
plt.show()

# %%
plt.figure()
sns.histplot(df["temp_deviation_c"], kde=True, bins=40, color="steelblue")
plt.title("Distribution of Temperature Deviation from Ideal Range")
plt.xlabel("Temp Deviation (°C)")
plt.tight_layout()
plt.savefig("chart2_temp_deviation_hist.png", dpi=150)
plt.show()

# %%
plt.figure()
sns.boxplot(data=df, x="commodity", y="quality_score", hue="commodity", palette="Set2", legend=False)
plt.title("Quality Score Distribution by Commodity")
plt.xticks(rotation=30)
plt.tight_layout()
plt.savefig("chart3_quality_by_commodity.png", dpi=150)
plt.show()

# %%
plt.figure()
sns.scatterplot(
    data=df.sample(min(5000, len(df)), random_state=1),  # sample for readability
    x="hours_in_transit",
    y="quality_score",
    hue="risk_status",
    alpha=0.5,
    s=20,
    palette="viridis",
)
plt.title("Quality Score vs Hours in Transit (by Risk Status)")
plt.tight_layout()
plt.savefig("chart4_quality_vs_transit_scatter.png", dpi=150)
plt.show()

# %%
fig, axes = plt.subplots(1, 2, figsize=(14, 5))

sns.countplot(data=df, x="risk_status", order=df["risk_status"].value_counts().index,
              ax=axes[0], hue="risk_status", palette="rocket", legend=False)
axes[0].set_title("Reading Count by Risk Status")
axes[0].tick_params(axis="x", rotation=20)

sns.countplot(data=df, x="recommended_action", order=df["recommended_action"].value_counts().index,
              ax=axes[1], hue="recommended_action", palette="mako", legend=False)
axes[1].set_title("Reading Count by Recommended Action")
axes[1].tick_params(axis="x", rotation=20)

plt.tight_layout()
plt.savefig("chart5_risk_and_action_counts.png", dpi=150)
plt.show()

# %%
numeric_cols = [
    "temperature_c", "humidity_pct", "vibration_g", "temp_deviation_c",
    "humidity_deviation_pct", "quality_score", "shelf_life_hours_remaining",
    "primary_price_per_kg_usd", "secondary_price_per_kg_usd", "arbitrage_gain_usd",
]

plt.figure(figsize=(9, 7))
sns.heatmap(df[numeric_cols].corr(), annot=True, fmt=".2f", cmap="coolwarm", center=0)
plt.title("Correlation Heatmap — Key Metrics")
plt.tight_layout()
plt.savefig("chart6_correlation_heatmap.png", dpi=150)
plt.show()

# %%
commodity = "Avocado"
sub = df[df["commodity"] == commodity].sort_values("Date_Time")

plt.figure()
plt.plot(sub["Date_Time"], sub["primary_price_per_kg_usd"], label="Primary Market Price")
plt.plot(sub["Date_Time"], sub["secondary_price_per_kg_usd"], label="Secondary Market Price")
plt.title(f"{commodity}: Primary vs Secondary Market Price Over Time")
plt.xlabel("Date/Time")
plt.ylabel("Price (USD/kg)")
plt.legend()
plt.xticks(rotation=30)
plt.tight_layout()
plt.savefig("chart7_price_comparison.png", dpi=150)
plt.show()

# %%
print("All charts saved as PNG files in the current directory.")
# Out:
# All charts saved as PNG files in the current directory.
